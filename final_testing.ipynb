# %%
from house_price_prediction_delhi import *
# Out:
# LR
# Training
# r2_score:  0.7610158283456536
# root_mean_square_error:  4098780.4654495977
# mean_absolute_error:  2212392.8900850923
# mean_absolute_percentage_error:  0.27328432000251646
#
# Testing
# r2_score:  0.735803038400284
# root_mean_square_error:  4005319.355598984
# mean_absolute_error:  2261842.4726544158
# mean_absolute_percentage_error:  0.2608074065782739
#
# KNR
# Training
# r2_score:  0.8118598695086131
# root_mean_square_error:  3636727.907650875
# mean_absolute_error:  1645298.1068513123
# mean_absolute_percentage_error:  0.15705182869761242
#
# Testing
# r2_score:  0.7648545143742747
# root_mean_square_error:  3778692.596737971
# mean_absolute_error:  2017045.4827988336
# mean_absolute_percentage_error:  0.20878962109293675
#
# DTR
# Training
# r2_score:  0.9954275229258319
# root_mean_square_error:  566951.4327476509
# mean_absolute_error:  107221.49451617381
# mean_absolute_percentage_error:  0.015399868061821264
#
# Testing
# r2_score:  0.6186253367684582
# ...
